# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"16637886794","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":281923424,"name":"wang-xue-qiang/bigdata-analysis","url":"https://api.github.com/repos/wang-xue-qiang/bigdata-analysis"},"payload":{"ref":"dependabot/maven/bigdata-analysis-echarts/org.apache.httpcomponents-httpclient-4.5.13","ref_type":"branch","master_branch":"master","description":"大数据收集，实时分析，离线分析经典案例","pusher_type":"user"},"public":true,"created_at":"2021-06-04T02:55:18Z"},{"id":"16637886791","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":246986670,"name":"Poornima-Puttaramu/OktaReusableArtifacts","url":"https://api.github.com/repos/Poornima-Puttaramu/OktaReusableArtifacts"},"payload":{"ref":"dependabot/maven/BulkMigrationUtility/BulkMigrationUtility/org.apache.httpcomponents-httpclient-4.5.13","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-06-04T02:55:18Z"},{"id":"16637886793","type":"PullRequestEvent","actor":{"id":11748387,"login":"wenbobuaa","display_login":"wenbobuaa","gravatar_id":"","url":"https://api.github.com/users/wenbobuaa","avatar_url":"https://avatars.githubusercontent.com/u/11748387?"},"repo":{"id":62722937,"name":"tencentyun/qcloud-documents","url":"https://api.github.com/repos/tencentyun/qcloud-documents"},"payload":{"action":"opened","number":7581,"pull_request":{"url":"https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581","id":661395444,"node_id":"MDExOlB1bGxSZXF1ZXN0NjYxMzk1NDQ0","html_url":"https://github.com/tencentyun/qcloud-documents/pull/7581","diff_url":"https://github.com/tencentyun/qcloud-documents/pull/7581.diff","patch_url":"https://github.com/tencentyun/qcloud-documents/pull/7581.patch","issue_url":"https://api.github.com/repos/tencentyun/qcloud-documents/issues/7581","number":7581,"state":"open","locked":false,"title":"refine document","user":{"login":"wenbobuaa","id":11748387,"node_id":"MDQ6VXNlcjExNzQ4Mzg3","avatar_url":"https://avatars.githubusercontent.com/u/11748387?v=4","gravatar_id":"","url":"https://api.github.com/users/wenbobuaa","html_url":"https://github.com/wenbobuaa","followers_url":"https://api.github.com/users/wenbobuaa/followers","following_url":"https://api.github.com/users/wenbobuaa/following{/other_user}","gists_url":"https://api.github.com/users/wenbobuaa/gists{/gist_id}","starred_url":"https://api.github.com/users/wenbobuaa/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/wenbobuaa/subscriptions","organizations_url":"https://api.github.com/users/wenbobuaa/orgs","repos_url":"https://api.github.com/users/wenbobuaa/repos","events_url":"https://api.github.com/users/wenbobuaa/events{/privacy}","received_events_url":"https://api.github.com/users/wenbobuaa/received_events","type":"User","site_admin":false},"body":"根据最近客户工单共性问题，优化了文档","created_at":"2021-06-04T02:55:18Z","updated_at":"2021-06-04T02:55:18Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[{"login":"v-dhaichen","id":31986479,"node_id":"MDQ6VXNlcjMxOTg2NDc5","avatar_url":"https://avatars.githubusercontent.com/u/31986479?v=4","gravatar_id":"","url":"https://api.github.com/users/v-dhaichen","html_url":"https://github.com/v-dhaichen","followers_url":"https://api.github.com/users/v-dhaichen/followers","following_url":"https://api.github.com/users/v-dhaichen/following{/other_user}","gists_url":"https://api.github.com/users/v-dhaichen/gists{/gist_id}","starred_url":"https://api.github.com/users/v-dhaichen/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/v-dhaichen ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '16637886794',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 281923424,
#    'name': 'wang-xue-qiang/bigdata-analysis',
#    'url': 'https://api.github.com/repos/wang-xue-qiang/bigdata-analysis'},
#   'payload': {'ref': 'dependabot/maven/bigdata-analysis-echarts/org.apache.httpcomponents-httpclient-4.5.13',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '大数据收集，实时分析，离线分析经典案例',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886791',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 246986670,
#    'name': 'Poornima-Puttaramu/OktaReusableArtifacts',
#    'url': 'https://api.github.com/repos/Poornima-Puttaramu/OktaReusableArtifacts'},
#   'payload': {'ref': 'dependabot/maven/BulkMigrationUtility/BulkMigrationUtility/org.apache.httpcomponents-httpclient-4.5.13',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886793',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 11748387,
#    'login': 'wenbobuaa',
#    'display_login': 'wenbobuaa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wenbobuaa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11748387?'},
#   'repo': {'id': 62722937,
#    'name': 'tencentyun/qcloud-documents',
#    'url': 'https://api.github.com/repos/tencentyun/qcloud-documents'},
#   'payload': {'action': 'opened',
#    'number': 7581,
#    'pull_request': {'url': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581',
#     'id': 661395444,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYxMzk1NDQ0',
#     'html_url': 'https://github.com/tencentyun/qcloud-documents/pull/7581',
#     'diff_url': 'https://github.com/tencentyun/qcloud-documents/pull/7581.diff',
#     'patch_url': 'https://github.com/tencentyun/qcloud-documents/pull/7581.patch',
#     'issue_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/7581',
#     'number': 7581,
#     'state': 'open',
#     'locked': False,
#     'title': 'refine document',
#     'user': {'login': 'wenbobuaa',
#      'id': 11748387,
#      'node_id': 'MDQ6VXNlcjExNzQ4Mzg3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/11748387?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wenbobuaa',
#      'html_url': 'https://github.com/wenbobuaa',
#      'followers_url': 'https://api.github.com/users/wenbobuaa/followers',
#      'following_url': 'https://api.github.com/users/wenbobuaa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wenbobuaa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wenbobuaa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wenbobuaa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wenbobuaa/orgs',
#      'repos_url': 'https://api.github.com/users/wenbobuaa/repos',
#      'events_url': 'https://api.github.com/users/wenbobuaa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wenbobuaa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '根据最近客户工单共性问题，优化了文档',
#     'created_at': '2021-06-04T02:55:18Z',
#     'updated_at': '2021-06-04T02:55:18Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'v-dhaichen',
#       'id': 31986479,
#       'node_id': 'MDQ6VXNlcjMxOTg2NDc5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/31986479?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/v-dhaichen',
#       'html_url': 'https://github.com/v-dhaichen',
#       'followers_url': 'https://api.github.com/users/v-dhaichen/followers',
#       'following_url': 'https://api.github.com/users/v-dhaichen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/v-dhaichen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/v-dhaichen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/v-dhaichen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/v-dhaichen/orgs',
#       'repos_url': 'https://api.github.com/users/v-dhaichen/repos',
#       'events_url': 'https://api.github.com/users/v-dhaichen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/v-dhaichen/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581/commits',
#     'review_comments_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581/comments',
#     'review_comment_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/7581/comments',
#     'statuses_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/statuses/d6774c92c0f74147f3ec6891a59e84d7c37b6870',
#     'head': {'label': 'tencentyun:wenbo-java-refine',
#      'ref': 'wenbo-java-refine',
#      'sha': 'd6774c92c0f74147f3ec6891a59e84d7c37b6870',
#      'user': {'login': 'tencentyun',
#       'id': 12334581,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMzM0NTgx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12334581?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tencentyun',
#       'html_url': 'https://github.com/tencentyun',
#       'followers_url': 'https://api.github.com/users/tencentyun/followers',
#       'following_url': 'https://api.github.com/users/tencentyun/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tencentyun/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tencentyun/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tencentyun/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tencentyun/orgs',
#       'repos_url': 'https://api.github.com/users/tencentyun/repos',
#       'events_url': 'https://api.github.com/users/tencentyun/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tencentyun/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 62722937,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2MjcyMjkzNw==',
#       'name': 'qcloud-documents',
#       'full_name': 'tencentyun/qcloud-documents',
#       'private': False,
#       'owner': {'login': 'tencentyun',
#        'id': 12334581,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMzM0NTgx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12334581?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tencentyun',
#        'html_url': 'https://github.com/tencentyun',
#        'followers_url': 'https://api.github.com/users/tencentyun/followers',
#        'following_url': 'https://api.github.com/users/tencentyun/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tencentyun/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tencentyun/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tencentyun/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tencentyun/orgs',
#        'repos_url': 'https://api.github.com/users/tencentyun/repos',
#        'events_url': 'https://api.github.com/users/tencentyun/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tencentyun/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/tencentyun/qcloud-documents',
#       'description': '腾讯云官方文档',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tencentyun/qcloud-documents',
#       'forks_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/forks',
#       'keys_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/teams',
#       'hooks_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/events',
#       'assignees_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/tags',
#       'blobs_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/languages',
#       'stargazers_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/subscription',
#       'commits_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/merges',
#       'archive_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/downloads',
#       'issues_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/deployments',
#       'created_at': '2016-07-06T13:27:05Z',
#       'updated_at': '2021-06-04T02:46:45Z',
#       'pushed_at': '2021-06-04T02:55:03Z',
#       'git_url': 'git://github.com/tencentyun/qcloud-documents.git',
#       'ssh_url': 'git@github.com:tencentyun/qcloud-documents.git',
#       'clone_url': 'https://github.com/tencentyun/qcloud-documents.git',
#       'svn_url': 'https://github.com/tencentyun/qcloud-documents',
#       'homepage': '',
#       'size': 382352,
#       'stargazers_count': 1248,
#       'watchers_count': 1248,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2317,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 44,
#       'license': None,
#       'forks': 2317,
#       'open_issues': 44,
#       'watchers': 1248,
#       'default_branch': 'master'}},
#     'base': {'label': 'tencentyun:master',
#      'ref': 'master',
#      'sha': '4fbbca24082c17ec1df8e7594b016689e7dda339',
#      'user': {'login': 'tencentyun',
#       'id': 12334581,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMzM0NTgx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12334581?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tencentyun',
#       'html_url': 'https://github.com/tencentyun',
#       'followers_url': 'https://api.github.com/users/tencentyun/followers',
#       'following_url': 'https://api.github.com/users/tencentyun/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tencentyun/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tencentyun/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tencentyun/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tencentyun/orgs',
#       'repos_url': 'https://api.github.com/users/tencentyun/repos',
#       'events_url': 'https://api.github.com/users/tencentyun/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tencentyun/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 62722937,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2MjcyMjkzNw==',
#       'name': 'qcloud-documents',
#       'full_name': 'tencentyun/qcloud-documents',
#       'private': False,
#       'owner': {'login': 'tencentyun',
#        'id': 12334581,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMzM0NTgx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12334581?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tencentyun',
#        'html_url': 'https://github.com/tencentyun',
#        'followers_url': 'https://api.github.com/users/tencentyun/followers',
#        'following_url': 'https://api.github.com/users/tencentyun/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tencentyun/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tencentyun/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tencentyun/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tencentyun/orgs',
#        'repos_url': 'https://api.github.com/users/tencentyun/repos',
#        'events_url': 'https://api.github.com/users/tencentyun/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tencentyun/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/tencentyun/qcloud-documents',
#       'description': '腾讯云官方文档',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tencentyun/qcloud-documents',
#       'forks_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/forks',
#       'keys_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/teams',
#       'hooks_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/events',
#       'assignees_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/tags',
#       'blobs_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/languages',
#       'stargazers_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/subscription',
#       'commits_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/merges',
#       'archive_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/downloads',
#       'issues_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tencentyun/qcloud-documents/deployments',
#       'created_at': '2016-07-06T13:27:05Z',
#       'updated_at': '2021-06-04T02:46:45Z',
#       'pushed_at': '2021-06-04T02:55:03Z',
#       'git_url': 'git://github.com/tencentyun/qcloud-documents.git',
#       'ssh_url': 'git@github.com:tencentyun/qcloud-documents.git',
#       'clone_url': 'https://github.com/tencentyun/qcloud-documents.git',
#       'svn_url': 'https://github.com/tencentyun/qcloud-documents',
#       'homepage': '',
#       'size': 382352,
#       'stargazers_count': 1248,
#       'watchers_count': 1248,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2317,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 44,
#       'license': None,
#       'forks': 2317,
#       'open_issues': 44,
#       'watchers': 1248,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581'},
#      'html': {'href': 'https://github.com/tencentyun/qcloud-documents/pull/7581'},
#      'issue': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/7581'},
#      'comments': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/issues/7581/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/pulls/7581/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tencentyun/qcloud-documents/statuses/d6774c92c0f74147f3ec6891a59e84d7c37b6870'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 134,
#     'deletions': 37,
#     'changed_files': 9}},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z',
#   'org': {'id': 12334581,
#    'login': 'tencentyun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tencentyun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12334581?'}},
#  {'id': '16637886785',
#   'type': 'PushEvent',
#   'actor': {'id': 140648,
#    'login': 'CostaBru',
#    'display_login': 'CostaBru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CostaBru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/140648?'},
#   'repo': {'id': 323993276,
#    'name': 'CostaBru/knapsack',
#    'url': 'https://api.github.com/repos/CostaBru/knapsack'},
#   'payload': {'push_id': 7256756632,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/main',
#    'head': 'fd98face6b0e019e9147ae93187e18bbad5ab267',
#    'before': '1f2f15c16177cea8221fb5281edc961d2c3f20da',
#    'commits': [{'sha': 'f744e3c9511f25a87d764dfca9e39572c181cb02',
#      'author': {'email': 'kooltew@gmail.com',
#       'name': 'Konstantin Briukhnov (Costa Bru)'},
#      'message': 'APIs extracted. First version of greedy solver added.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CostaBru/knapsack/commits/f744e3c9511f25a87d764dfca9e39572c181cb02'},
#     {'sha': '6cd351fa5612b134f806cdc6a7c7a0b27b4e5b7a',
#      'author': {'email': 'kooltew@gmail.com',
#       'name': 'Konstantin Briukhnov (Costa Bru)'},
#      'message': 'First working version.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CostaBru/knapsack/commits/6cd351fa5612b134f806cdc6a7c7a0b27b4e5b7a'},
#     {'sha': '3c2e3c94dade632f34a5eea054c386c8566e7e35',
#      'author': {'email': 'kooltew@gmail.com',
#       'name': 'Konstantin Briukhnov (Costa Bru)'},
#      'message': 'N dimension greedy knapsack solver implemented. Greedy test added.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CostaBru/knapsack/commits/3c2e3c94dade632f34a5eea054c386c8566e7e35'},
#     {'sha': 'fd98face6b0e019e9147ae93187e18bbad5ab267',
#      'author': {'email': 'kooltew@gmail.com',
#       'name': 'Konstantin Briukhnov (Costa Bru)'},
#      'message': 'Unnecessary sort was removed in greedy algo.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CostaBru/knapsack/commits/fd98face6b0e019e9147ae93187e18bbad5ab267'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886797',
#   'type': 'PushEvent',
#   'actor': {'id': 58677001,
#    'login': 'limjeehun',
#    'display_login': 'limjeehun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/limjeehun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58677001?'},
#   'repo': {'id': 349305571,
#    'name': 'limjeehun/ml_agent_test',
#    'url': 'https://api.github.com/repos/limjeehun/ml_agent_test'},
#   'payload': {'push_id': 7256756645,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8e4ac5f6aeb97ab3b8395bc3e0ede75ffdf9b988',
#    'before': 'a6b90bcd19502ff1f093786234a831274c1ecc9b',
#    'commits': [{'sha': '8e4ac5f6aeb97ab3b8395bc3e0ede75ffdf9b988',
#      'author': {'email': '58677001+limjeehun@users.noreply.github.com',
#       'name': 'LIMJEEHUN'},
#      'message': 'Delete 박선용 directory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/limjeehun/ml_agent_test/commits/8e4ac5f6aeb97ab3b8395bc3e0ede75ffdf9b988'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886783',
#   'type': 'PushEvent',
#   'actor': {'id': 47669903,
#    'login': 'WLTN1',
#    'display_login': 'WLTN1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WLTN1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47669903?'},
#   'repo': {'id': 343239510,
#    'name': 'WLTN1/itsterez-nodayoff',
#    'url': 'https://api.github.com/repos/WLTN1/itsterez-nodayoff'},
#   'payload': {'push_id': 7256756630,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '43aacd4c8558351513810838a8f09a851342b37f',
#    'before': '7bf61abd7537a60d5ba8dd7ab60d444a85874f8c',
#    'commits': [{'sha': '43aacd4c8558351513810838a8f09a851342b37f',
#      'author': {'email': '47669903+WLTN1@users.noreply.github.com',
#       'name': 'WLTN1'},
#      'message': 'Automated update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/WLTN1/itsterez-nodayoff/commits/43aacd4c8558351513810838a8f09a851342b37f'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886782',
#   'type': 'WatchEvent',
#   'actor': {'id': 23627652,
#    'login': 'lingluoer',
#    'display_login': 'lingluoer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lingluoer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23627652?'},
#   'repo': {'id': 86843046,
#    'name': 'Hootrix/Chengdu-IT-company-blacklist',
#    'url': 'https://api.github.com/repos/Hootrix/Chengdu-IT-company-blacklist'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886757',
#   'type': 'WatchEvent',
#   'actor': {'id': 547971,
#    'login': 'hiessu',
#    'display_login': 'hiessu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hiessu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/547971?'},
#   'repo': {'id': 59818097,
#    'name': 'EarsEyesMouth/computerese-cross-references',
#    'url': 'https://api.github.com/repos/EarsEyesMouth/computerese-cross-references'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z',
#   'org': {'id': 20242894,
#    'login': 'EarsEyesMouth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/EarsEyesMouth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20242894?'}},
#  {'id': '16637886775',
#   'type': 'CreateEvent',
#   'actor': {'id': 60644983,
#    'login': 'mlph-kvillegas',
#    'display_login': 'mlph-kvillegas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mlph-kvillegas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60644983?'},
#   'repo': {'id': 373703017,
#    'name': 'mlph-kvillegas/load-text-file-asset',
#    'url': 'https://api.github.com/repos/mlph-kvillegas/load-text-file-asset'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Sample code for loading a text file on a flutter project ',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886755',
#   'type': 'PushEvent',
#   'actor': {'id': 83887914,
#    'login': 'fbteixeira',
#    'display_login': 'fbteixeira',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fbteixeira',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83887914?'},
#   'repo': {'id': 369294846,
#    'name': 'fbteixeira/cadastropessoal',
#    'url': 'https://api.github.com/repos/fbteixeira/cadastropessoal'},
#   'payload': {'push_id': 7256756617,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fernanda',
#    'head': '5f12caccced24f61ea18172a1d7496a10a6e20e4',
#    'before': '2fa4221a6eb01e997ff700442b58c73edea16a14',
#    'commits': [{'sha': '5f12caccced24f61ea18172a1d7496a10a6e20e4',
#      'author': {'email': 'fernandabrandaoteixeira@gmail.com',
#       'name': 'Fernanda Teixeira'},
#      'message': 'ordenar codigo js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fbteixeira/cadastropessoal/commits/5f12caccced24f61ea18172a1d7496a10a6e20e4'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886747',
#   'type': 'PushEvent',
#   'actor': {'id': 65356582,
#    'login': 'stukusva',
#    'display_login': 'stukusva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stukusva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65356582?'},
#   'repo': {'id': 263954735,
#    'name': 'StukFi/stukfi.github.io',
#    'url': 'https://api.github.com/repos/StukFi/stukfi.github.io'},
#   'payload': {'push_id': 7256756604,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '46fd6accf577f2e17aa430e2e3cb5ae13c6e0dfb',
#    'before': '873793841f6b35881185d518335f2f87cc991263',
#    'commits': [{'sha': '46fd6accf577f2e17aa430e2e3cb5ae13c6e0dfb',
#      'author': {'email': 'usva.stuk@gmail.com', 'name': 'USVA bot'},
#      'message': 'update latest data programmatically',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/StukFi/stukfi.github.io/commits/46fd6accf577f2e17aa430e2e3cb5ae13c6e0dfb'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z',
#   'org': {'id': 44080343,
#    'login': 'StukFi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/StukFi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44080343?'}},
#  {'id': '16637886772',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 206009614,
#    'name': 'nvhanzijiuba/wxpay',
#    'url': 'https://api.github.com/repos/nvhanzijiuba/wxpay'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/pulls/2',
#     'id': 661395441,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjYxMzk1NDQx',
#     'html_url': 'https://github.com/nvhanzijiuba/wxpay/pull/2',
#     'diff_url': 'https://github.com/nvhanzijiuba/wxpay/pull/2.diff',
#     'patch_url': 'https://github.com/nvhanzijiuba/wxpay/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump httpclient from 4.5.6 to 4.5.13 in /微信小程序支付demo/java后端/wxpay',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "Bumps httpclient from 4.5.6 to 4.5.13.\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=org.apache.httpcomponents:httpclient&package-manager=maven&previous-version=4.5.6&new-version=4.5.13)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/nvhanzijiuba/wxpay/network/alerts).\n\n</details>",
#     'created_at': '2021-06-04T02:55:18Z',
#     'updated_at': '2021-06-04T02:55:18Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/statuses/eaecb40af4ff4ee351b145facbbfd3b7fbeb52fb',
#     'head': {'label': 'nvhanzijiuba:dependabot/maven/demo/java/wxpay/org.apache.httpcomponents-httpclient-4.5.13',
#      'ref': 'dependabot/maven/demo/java/wxpay/org.apache.httpcomponents-httpclient-4.5.13',
#      'sha': 'eaecb40af4ff4ee351b145facbbfd3b7fbeb52fb',
#      'user': {'login': 'nvhanzijiuba',
#       'id': 49189268,
#       'node_id': 'MDQ6VXNlcjQ5MTg5MjY4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49189268?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nvhanzijiuba',
#       'html_url': 'https://github.com/nvhanzijiuba',
#       'followers_url': 'https://api.github.com/users/nvhanzijiuba/followers',
#       'following_url': 'https://api.github.com/users/nvhanzijiuba/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nvhanzijiuba/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nvhanzijiuba/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nvhanzijiuba/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nvhanzijiuba/orgs',
#       'repos_url': 'https://api.github.com/users/nvhanzijiuba/repos',
#       'events_url': 'https://api.github.com/users/nvhanzijiuba/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nvhanzijiuba/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 206009614,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDYwMDk2MTQ=',
#       'name': 'wxpay',
#       'full_name': 'nvhanzijiuba/wxpay',
#       'private': False,
#       'owner': {'login': 'nvhanzijiuba',
#        'id': 49189268,
#        'node_id': 'MDQ6VXNlcjQ5MTg5MjY4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/49189268?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/nvhanzijiuba',
#        'html_url': 'https://github.com/nvhanzijiuba',
#        'followers_url': 'https://api.github.com/users/nvhanzijiuba/followers',
#        'following_url': 'https://api.github.com/users/nvhanzijiuba/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/nvhanzijiuba/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/nvhanzijiuba/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/nvhanzijiuba/subscriptions',
#        'organizations_url': 'https://api.github.com/users/nvhanzijiuba/orgs',
#        'repos_url': 'https://api.github.com/users/nvhanzijiuba/repos',
#        'events_url': 'https://api.github.com/users/nvhanzijiuba/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/nvhanzijiuba/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/nvhanzijiuba/wxpay',
#       'description': '微信支付',
#       'fork': False,
#       'url': 'https://api.github.com/repos/nvhanzijiuba/wxpay',
#       'forks_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/forks',
#       'keys_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/teams',
#       'hooks_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/hooks',
#       'issue_events_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/events',
#       'assignees_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/tags',
#       'blobs_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/languages',
#       'stargazers_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/stargazers',
#       'contributors_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/contributors',
#       'subscribers_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/subscribers',
#       'subscription_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/subscription',
#       'commits_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/merges',
#       'archive_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/downloads',
#       'issues_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/deployments',
#       'created_at': '2019-09-03T06:56:32Z',
#       'updated_at': '2020-12-14T15:21:02Z',
#       'pushed_at': '2021-06-04T02:55:18Z',
#       'git_url': 'git://github.com/nvhanzijiuba/wxpay.git',
#       'ssh_url': 'git@github.com:nvhanzijiuba/wxpay.git',
#       'clone_url': 'https://github.com/nvhanzijiuba/wxpay.git',
#       'svn_url': 'https://github.com/nvhanzijiuba/wxpay',
#       'homepage': None,
#       'size': 50372,
#       'stargazers_count': 7,
#       'watchers_count': 7,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 2,
#       'open_issues': 2,
#       'watchers': 7,
#       'default_branch': 'master'}},
#     'base': {'label': 'nvhanzijiuba:master',
#      'ref': 'master',
#      'sha': 'e6a26d2569e1f443d75d561ffd0bc041ebc5c9ab',
#      'user': {'login': 'nvhanzijiuba',
#       'id': 49189268,
#       'node_id': 'MDQ6VXNlcjQ5MTg5MjY4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49189268?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nvhanzijiuba',
#       'html_url': 'https://github.com/nvhanzijiuba',
#       'followers_url': 'https://api.github.com/users/nvhanzijiuba/followers',
#       'following_url': 'https://api.github.com/users/nvhanzijiuba/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nvhanzijiuba/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nvhanzijiuba/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nvhanzijiuba/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nvhanzijiuba/orgs',
#       'repos_url': 'https://api.github.com/users/nvhanzijiuba/repos',
#       'events_url': 'https://api.github.com/users/nvhanzijiuba/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nvhanzijiuba/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 206009614,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDYwMDk2MTQ=',
#       'name': 'wxpay',
#       'full_name': 'nvhanzijiuba/wxpay',
#       'private': False,
#       'owner': {'login': 'nvhanzijiuba',
#        'id': 49189268,
#        'node_id': 'MDQ6VXNlcjQ5MTg5MjY4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/49189268?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/nvhanzijiuba',
#        'html_url': 'https://github.com/nvhanzijiuba',
#        'followers_url': 'https://api.github.com/users/nvhanzijiuba/followers',
#        'following_url': 'https://api.github.com/users/nvhanzijiuba/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/nvhanzijiuba/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/nvhanzijiuba/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/nvhanzijiuba/subscriptions',
#        'organizations_url': 'https://api.github.com/users/nvhanzijiuba/orgs',
#        'repos_url': 'https://api.github.com/users/nvhanzijiuba/repos',
#        'events_url': 'https://api.github.com/users/nvhanzijiuba/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/nvhanzijiuba/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/nvhanzijiuba/wxpay',
#       'description': '微信支付',
#       'fork': False,
#       'url': 'https://api.github.com/repos/nvhanzijiuba/wxpay',
#       'forks_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/forks',
#       'keys_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/teams',
#       'hooks_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/hooks',
#       'issue_events_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/events',
#       'assignees_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/tags',
#       'blobs_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/languages',
#       'stargazers_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/stargazers',
#       'contributors_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/contributors',
#       'subscribers_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/subscribers',
#       'subscription_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/subscription',
#       'commits_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/merges',
#       'archive_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/downloads',
#       'issues_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/nvhanzijiuba/wxpay/notifications{?since,all,participating}',
# ...
#       'private': False,
#       'owner': {'login': 'weijiangpeng',
#        'id': 51870682,
#        'node_id': 'MDQ6VXNlcjUxODcwNjgy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/51870682?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/weijiangpeng',
#        'html_url': 'https://github.com/weijiangpeng',
#        'followers_url': 'https://api.github.com/users/weijiangpeng/followers',
#        'following_url': 'https://api.github.com/users/weijiangpeng/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/weijiangpeng/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/weijiangpeng/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/weijiangpeng/subscriptions',
#        'organizations_url': 'https://api.github.com/users/weijiangpeng/orgs',
#        'repos_url': 'https://api.github.com/users/weijiangpeng/repos',
#        'events_url': 'https://api.github.com/users/weijiangpeng/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/weijiangpeng/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/weijiangpeng/Study_Code',
#       'description': 'My study code.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/weijiangpeng/Study_Code',
#       'forks_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/forks',
#       'keys_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/teams',
#       'hooks_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/hooks',
#       'issue_events_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/events',
#       'assignees_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/tags',
#       'blobs_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/languages',
#       'stargazers_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/stargazers',
#       'contributors_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/contributors',
#       'subscribers_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/subscribers',
#       'subscription_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/subscription',
#       'commits_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/merges',
#       'archive_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/downloads',
#       'issues_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/deployments',
#       'created_at': '2019-11-04T04:54:22Z',
#       'updated_at': '2020-05-23T06:46:38Z',
#       'pushed_at': '2021-06-04T02:55:17Z',
#       'git_url': 'git://github.com/weijiangpeng/Study_Code.git',
#       'ssh_url': 'git@github.com:weijiangpeng/Study_Code.git',
#       'clone_url': 'https://github.com/weijiangpeng/Study_Code.git',
#       'svn_url': 'https://github.com/weijiangpeng/Study_Code',
#       'homepage': '',
#       'size': 225497,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 15,
#       'license': None,
#       'forks': 0,
#       'open_issues': 15,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'weijiangpeng:master',
#      'ref': 'master',
#      'sha': '04b090063df63f7a63e250008088845a7b0e53f8',
#      'user': {'login': 'weijiangpeng',
#       'id': 51870682,
#       'node_id': 'MDQ6VXNlcjUxODcwNjgy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/51870682?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/weijiangpeng',
#       'html_url': 'https://github.com/weijiangpeng',
#       'followers_url': 'https://api.github.com/users/weijiangpeng/followers',
#       'following_url': 'https://api.github.com/users/weijiangpeng/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/weijiangpeng/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/weijiangpeng/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/weijiangpeng/subscriptions',
#       'organizations_url': 'https://api.github.com/users/weijiangpeng/orgs',
#       'repos_url': 'https://api.github.com/users/weijiangpeng/repos',
#       'events_url': 'https://api.github.com/users/weijiangpeng/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/weijiangpeng/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 219420098,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTk0MjAwOTg=',
#       'name': 'Study_Code',
#       'full_name': 'weijiangpeng/Study_Code',
#       'private': False,
#       'owner': {'login': 'weijiangpeng',
#        'id': 51870682,
#        'node_id': 'MDQ6VXNlcjUxODcwNjgy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/51870682?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/weijiangpeng',
#        'html_url': 'https://github.com/weijiangpeng',
#        'followers_url': 'https://api.github.com/users/weijiangpeng/followers',
#        'following_url': 'https://api.github.com/users/weijiangpeng/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/weijiangpeng/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/weijiangpeng/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/weijiangpeng/subscriptions',
#        'organizations_url': 'https://api.github.com/users/weijiangpeng/orgs',
#        'repos_url': 'https://api.github.com/users/weijiangpeng/repos',
#        'events_url': 'https://api.github.com/users/weijiangpeng/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/weijiangpeng/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/weijiangpeng/Study_Code',
#       'description': 'My study code.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/weijiangpeng/Study_Code',
#       'forks_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/forks',
#       'keys_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/teams',
#       'hooks_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/hooks',
#       'issue_events_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/events',
#       'assignees_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/tags',
#       'blobs_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/languages',
#       'stargazers_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/stargazers',
#       'contributors_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/contributors',
#       'subscribers_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/subscribers',
#       'subscription_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/subscription',
#       'commits_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/merges',
#       'archive_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/downloads',
#       'issues_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/weijiangpeng/Study_Code/deployments',
#       'created_at': '2019-11-04T04:54:22Z',
#       'updated_at': '2020-05-23T06:46:38Z',
#       'pushed_at': '2021-06-04T02:55:17Z',
#       'git_url': 'git://github.com/weijiangpeng/Study_Code.git',
#       'ssh_url': 'git@github.com:weijiangpeng/Study_Code.git',
#       'clone_url': 'https://github.com/weijiangpeng/Study_Code.git',
#       'svn_url': 'https://github.com/weijiangpeng/Study_Code',
#       'homepage': '',
#       'size': 225497,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 15,
#       'license': None,
#       'forks': 0,
#       'open_issues': 15,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/pulls/17'},
#      'html': {'href': 'https://github.com/weijiangpeng/Study_Code/pull/17'},
#      'issue': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues/17'},
#      'comments': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/issues/17/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/pulls/17/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/pulls/17/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/weijiangpeng/Study_Code/statuses/4403c4e03f33eb2c6190a1c74ccbd9496dd009e9'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886701',
#   'type': 'PushEvent',
#   'actor': {'id': 84603997,
#    'login': 'denglichi',
#    'display_login': 'denglichi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/denglichi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84603997?'},
#   'repo': {'id': 369671386,
#    'name': 'denglichi/Coursera_Capstone',
#    'url': 'https://api.github.com/repos/denglichi/Coursera_Capstone'},
#   'payload': {'push_id': 7256756594,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3c092c6454c26810a7f43a62bc4a0d14d4fde12d',
#    'before': '34a1b5b74c0bebaf5aac380d7651cfab19c8947d',
#    'commits': [{'sha': '3c092c6454c26810a7f43a62bc4a0d14d4fde12d',
#      'author': {'email': 'denglichi.ld@gmail.com', 'name': 'denglichi'},
#      'message': 'Week 4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/denglichi/Coursera_Capstone/commits/3c092c6454c26810a7f43a62bc4a0d14d4fde12d'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'},
#  {'id': '16637886694',
#   'type': 'PushEvent',
#   'actor': {'id': 79386264,
#    'login': 'indiraprakoso',
#    'display_login': 'indiraprakoso',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/indiraprakoso',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79386264?'},
#   'repo': {'id': 373702430,
#    'name': 'indiraprakoso/Genomictoolkit',
#    'url': 'https://api.github.com/repos/indiraprakoso/Genomictoolkit'},
#   'payload': {'push_id': 7256756590,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a677a8df83af12f95da6814182dd55aca4077d9a',
#    'before': '079130dedad286252e40ffe11758e069f059e0de',
#    'commits': [{'sha': 'a677a8df83af12f95da6814182dd55aca4077d9a',
#      'author': {'email': '79386264+indiraprakoso@users.noreply.github.com',
#       'name': 'Indira Prakoso'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/indiraprakoso/Genomictoolkit/commits/a677a8df83af12f95da6814182dd55aca4077d9a'}]},
#   'public': True,
#   'created_at': '2021-06-04T02:55:18Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-60b99767-796da5f53f90dc3f63a3da76'},
#  'origin': '1.170.27.16',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-60b99774-73003a8b45a14a457ecfd185'},
#  'json': None,
#  'origin': '1.170.27.16',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-60b99777-4922280a63b1560a1a235a14'},
#  'json': None,
#  'origin': '1.170.27.16',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
