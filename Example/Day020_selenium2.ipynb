# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 觀察 API 請求資訊

# %% [markdown]
# ![](https://imgur.com/qBmCUxR.jpg)

# %% [markdown]
# ![](https://imgur.com/Xi5kYFX.jpg)

# %%
import requests
import json

r = requests.get('https://fhy.wra.gov.tw/fhy/api/ReservoirInfoApi/DryAreaGetAll')
d = json.loads(r.text)

d
# Out:
# [{'AREA_NO': 'A01',
#   'AREA_NAME': '北區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 245.0,
#     'Capacity': 10629.234,
#     'CapacityRate': 52.44834477279793,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 20266.07,
#     'StationNo': '10201',
#     'StationName': '石門水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T08:00:00',
#     'NWL_MX': 86.0,
#     'Capacity': 942.0,
#     'CapacityRate': 94.01197604790418,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 989.5,
#     'StationNo': '10204',
#     'StationName': '新山水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 170.0,
#     'Capacity': 28952.72,
#     'CapacityRate': 86.29594193827216,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 33398.8,
#     'StationNo': '10205',
#     'StationName': '翡翠水庫',
#     'BasinNo': '1140',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 150.0,
#     'Capacity': 2279.17,
#     'CapacityRate': 72.41943581237807,
#     'Status': 5,
#     'Basin_Rain': 0.2,
#     'EffectiveCapacity': 3169.0,
#     'StationNo': '10405',
#     'StationName': '寶山第二水庫',
#     'BasinNo': '1300',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 85.0,
#     'Capacity': 927.408,
#     'CapacityRate': 30.924526666088685,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 2998.94,
#     'StationNo': '10501',
#     'StationName': '永和山水庫',
#     'BasinNo': '105',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 61.0,
#     'Capacity': 736.0833,
#     'CapacityRate': 60.233652300984275,
#     'Status': 5,
#     'Basin_Rain': 0.0,
#     'EffectiveCapacity': 1222.0,
#     'StationNo': '10601',
#     'StationName': '明德水庫',
#     'BasinNo': '1350',
#     'Basin': None}]},
#  {'AREA_NO': 'A02',
#   'AREA_NAME': '中區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T15:00:00',
#     'NWL_MX': 300.0,
#     'Capacity': 4617.49,
#     'CapacityRate': 40.34148144200468,
#     'Status': 5,
#     'Basin_Rain': 8.2,
#     'EffectiveCapacity': 11446.0,
#     'StationNo': '20101',
#     'StationName': '鯉魚潭水庫',
#     'BasinNo': '1400',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 1408.0,
#     'Capacity': 4286.79,
#     'CapacityRate': 22.99533311876408,
#     'Status': 5,
#     'Basin_Rain': 0.5,
#     'EffectiveCapacity': 15018.0,
#     'StationNo': '20201',
#     'StationName': '德基水庫',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 274.5,
#     'Capacity': 121.43,
#     'CapacityRate': 81.32743955528767,
#     'Status': 5,
#     'Basin_Rain': 20.0,
#     'EffectiveCapacity': 144.56,
#     'StationNo': '20202',
#     'StationName': '石岡壩',
#     'BasinNo': '1420',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 1005.0,
#     'Capacity': 1225.06,
#     'CapacityRate': 32.643196691607514,
#     'Status': 5,
#     'Basin_Rain': 14.5,
#     'EffectiveCapacity': 3752.88,
#     'StationNo': '20501',
#     'StationName': '霧社水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 748.48,
#     'Capacity': 10828.86,
#     'CapacityRate': 84.56063276440864,
#     'Status': 5,
#     'Basin_Rain': 6.0,
#     'EffectiveCapacity': 12806.0,
#     'StationNo': '20502',
#     'StationName': '日月潭水庫',
#     'BasinNo': '1510',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 211.5,
#     'Capacity': 4108.75,
#     'CapacityRate': 80.7773578436461,
#     'Status': 5,
#     'Basin_Rain': 8.0,
#     'EffectiveCapacity': 5087.0,
#     'StationNo': '20509',
#     'StationName': '湖山水庫',
#     'BasinNo': '1510',
#     'Basin': None}]},
#  {'AREA_NO': 'A03',
#   'AREA_NAME': '南區',
#   'Warns': None,
#   'DryView': [{'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 105.0,
#     'Capacity': 1951.61,
#     'CapacityRate': 77.21625663709811,
#     'Status': 5,
#     'Basin_Rain': 38.5,
#     'EffectiveCapacity': 2527.5,
#     'StationNo': '30301',
#     'StationName': '仁義潭水庫',
#     'BasinNo': '1580',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T08:00:00',
#     'NWL_MX': 109.0,
#     'Capacity': 306.0,
#     'CapacityRate': 26.076952575738204,
#     'Status': 5,
#     'Basin_Rain': 30.9,
#     'EffectiveCapacity': 1173.45,
#     'StationNo': '30401',
#     'StationName': '白河水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 58.18,
#     'Capacity': 4682.0,
#     'CapacityRate': 59.58334924089134,
#     'Status': 5,
#     'Basin_Rain': 47.6,
#     'EffectiveCapacity': 7857.9,
#     'StationNo': '30501',
#     'StationName': '烏山頭水庫',
#     'BasinNo': '1590',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 230.0,
#     'Capacity': 11371.0,
#     'CapacityRate': 22.315330873694954,
#     'Status': 5,
#     'Basin_Rain': 24.6,
#     'EffectiveCapacity': 50956.0,
#     'StationNo': '30502',
#     'StationName': '曾文水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T07:00:00',
#     'NWL_MX': 180.0,
#     'Capacity': 7529.57,
#     'CapacityRate': 82.7616263093681,
#     'Status': 5,
#     'Basin_Rain': 36.0,
#     'EffectiveCapacity': 9097.9,
#     'StationNo': '30503',
#     'StationName': '南化水庫',
#     'BasinNo': '1630',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 37.0,
#     'Capacity': 109.0,
#     'CapacityRate': 7.14335802051651,
#     'Status': 5,
#     'Basin_Rain': 34.0,
#     'EffectiveCapacity': 1525.9,
#     'StationNo': '30802',
#     'StationName': '阿公店水庫',
#     'BasinNo': '308',
#     'Basin': None},
#    {'AREA_NO': None,
#     'AREA_Name': None,
#     'DATE': '2021-06-17T16:00:00',
#     'NWL_MX': 142.0,
#     'Capacity': 850.0,
#     'CapacityRate': 32.05953871227016,
#     'Status': 5,
#     'Basin_Rain': 4.6,
#     'EffectiveCapacity': 2651.317,
#     'StationNo': '31201',
#     'StationName': '牡丹水庫',
#     'BasinNo': '312',
#     'Basin': None}]}]

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。
